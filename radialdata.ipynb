# %% [markdown]
# ### радиальные данные

# %%
import os
from collections import namedtuple

def isBlank (myString):
    if myString and myString.strip():
        #myString is not None AND myString is not empty or blank
        return False
    #myString is None OR myString is empty or blank
    return True

# %%
def read_radial(f):
    Icms_path = os.path.abspath(f)
    file = open(Icms_path)

    for i in range(7):
        header = file.readline().split()
        print(header)

    header = file.readline().split()
    print(header)

    profiles = { h: [] for h in header }

    lines = file.readlines()
    table = []
    for line in lines:
        if isBlank(line):
            break
        table.append(line.split())
        
    print(len(table))
  
    rays = []
    N_traj = 0
    TRay = namedtuple('Ray' , 'R Z N_traj')
    ray = TRay ([], [], 123)

    for row in table:
        for index, (p, item) in enumerate(profiles.items()):
            #print(p, item, index)
            item.append(float(row[index]))

    return profiles, 123


profiles , w = read_radial("data/readme.showdata.2")
# Out:
# ['Ext', 'format']
# ['-Upgrade', 'R=1.6', 'a=.5', 'B=2.5', 'I=1', 'q=5.31', '<n>=4.08', 'Time=******', 'dt=15']
# []
# ['Writing', 'radial', 'data']
# ['Time', 'AB', 'NAB', 'ABC', 'NA1', 'NB1', 'mu']
# ['100.4', '0.6', '144.0', '0.5', '121.0', '144.0', '0.2']
# []
# ['a', 'Tex', 'psiN', 'car1', 'vert', 'nex', 'Ti', 'car2', 'All', 'Te', 'sqps', 'cax1', 'horz', 'ne', 'prad', 'cax2', 'Zeff']
# 121

# %%
import matplotlib.pyplot as plt

grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

fig.suptitle('Astra radial data')
ax1.plot(profiles['a'])
ax1.set_title("a")
ax1.set_box_aspect(1)

ax2.plot(profiles['Tex'])
ax2.set_title("Tex")
ax2.set_box_aspect(1)

ax3.plot(profiles['psiN'])
ax3.set_title("psiN")
ax3.set_box_aspect(1)

ax4.plot(profiles['car1'])
ax4.plot(profiles['vert'])
ax4.set_title("car1, vert")
ax4.set_box_aspect(1)

# %%
fig = plt.figure(figsize=(10, 9))

ax1 = plt.subplot2grid((3, 3), (0, 0))
ax2 = plt.subplot2grid((3, 3), (0, 1), colspan=2)
ax3 = plt.subplot2grid((3, 3), (1, 0), colspan=2, rowspan=2)
ax4 = plt.subplot2grid((3, 3), (1, 2), rowspan=2)

ax1.plot(profiles['a'])
ax1.set_title("a")
#ax1.set_box_aspect(1)

ax2.plot(profiles['Tex'])
ax2.set_title("Tex")
#ax2.set_box_aspect(1)

ax3.plot(profiles['psiN'])
ax3.set_title("psiN")
#ax3.set_box_aspect(1)

ax4.plot(profiles['car1'])
ax4.plot(profiles['vert'])
ax4.set_title("car1, vert")
#ax4.set_box_aspect(1)
# Out:
# Text(0.5, 1.0, 'car1, vert')
