# %% [markdown]
# ## Reading and drawing lcms.dat file
# Читение и парсинг файла с последней магнитной поверхностью, и потом рисую ее.

# %%
import bounds
R, Z = bounds.read_bounds()
# Out:
# ['R(m)', 'Z(m)']

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.plot(R, Z)
