# %% [markdown]
# ## Чтение из файлов и рисование траекторий и границы

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import astra_io as astra

rays, N_traj = astra.read_trajectories("data/traj_40167_a.dat")

print("Number of traj "+ str(len(rays)))
print("Max N_traj "+ str(N_traj))
# Out:
# Number of traj 346
# Max N_traj 1058

# %%
plt.figure(figsize=(6,6))

R, Z = astra.read_bounds("data/lcms.dat")
plt.plot(R, Z)

for ray in rays :
    plt.plot(ray.R, ray.Z, alpha=0.5, linewidth=1);
 
plt.show()
# Out:
# ['R(m)', 'Z(m)']

# %%
from ipywidgets import interactive

def plot_func(index, k):
    plt.figure(figsize=(6,6))
    plt.plot(R, Z)
    end_index = index+k if (index+k)<len(rays) else len(rays)
    for i in range(index, end_index):
        ray = rays[i]
        plt.plot(ray.R, ray.Z, alpha=1.0, linewidth=1)  
    plt.xlim(0.12, 0.62)
    plt.ylim(-0.5, 0.5)
    plt.show()
 
w = interactive(plot_func, index = (1, 1000), k = (1, 500))
w
# Out:
# interactive(children=(IntSlider(value=500, description='index', max=1000, min=1), IntSlider(value=250, descrip…
